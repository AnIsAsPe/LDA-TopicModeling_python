# %% [markdown]
# <a href="https://colab.research.google.com/github/AnIsAsPe/LDA-TopicModeling_python/blob/main/Notebooks/LDA_con_sklearn_noticias_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instalar y cargar bibliotecas

# %%
# !pip install pyLDAvis  #biblioteca que extrae información de un modelo LDA para obtener una visualización interactiva
# Out:
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.1.tar.gz (1.7 MB)
#      |████████████████████████████████| 1.7 MB 3.1 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.8.1)
# Collecting funcy
#   Downloading funcy-1.17-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.2)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from numexpr->pyLDAvis) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->numexpr->pyLDAvis) (3.0.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.1.0)
# Building wheels for collected packages: pyLDAvis
#   Building wheel for pyLDAvis (PEP 517) ... done
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.3.1-py2.py3-none-any.whl size=136898 sha256=19eb2154b0317abff8d16cfb4e7f2d58381eb4cb742997350ceef756a5de6d1f
#   Stored in directory: /root/.cache/pip/wheels/c9/21/f6/17bcf2667e8a68532ba2fbf6d5c72fdf4c7f7d9abfa4852d2f
# Successfully built pyLDAvis
# Installing collected packages: funcy, pyLDAvis
# Successfully installed funcy-1.17 pyLDAvis-3.3.1

# %%
import pandas as pd
import numpy as np

import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

import pyLDAvis
import matplotlib.pyplot as plt 
import seaborn as sns  

nltk.download('stopwords')
nltk.download('wordnet')  #WordNetLemmatizer
nltk.download('punkt')
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable
# /usr/local/lib/python3.7/dist-packages/past/builtins/misc.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Mapping
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# # Lectura y exploración de datos

# %% [markdown]
# En colab, al instalar la librería pyLDAvis causa un conflicto con Pandas. Si esto se refleja al correr la siguiente linea es necesario reiniciar el entorno de ejecución.

# %%
df = pd.read_csv('/content/drive/MyDrive/Datos/ABC News/abcnews-date-text.csv', parse_dates=['publish_date'] )
print(df.shape)
df.head()
# Out:
# (1226258, 2)
#   publish_date                                      headline_text
# 0   2003-02-19  aba decides against community broadcasting lic...
# 1   2003-02-19     act fire witnesses must be aware of defamation
# 2   2003-02-19     a g calls for infrastructure protection summit
# 3   2003-02-19           air nz staff in aust strike for pay rise
# 4   2003-02-19      air nz strike to affect australian travellers

# %%
df.publish_date.min(), df.publish_date.max()
# Out:
# (Timestamp('2003-02-19 00:00:00'), Timestamp('2020-12-31 00:00:00'))

# %%
# promedio de noticias por día
len(df)/(df.publish_date.max()-df.publish_date.min()).days
# Out:
# 187.93226053639847

# %%
filtro = (df['publish_date']>= '2020-01-01')&(df['publish_date']<= '2020-12-31')
df = df[filtro]
df = df.reset_index(drop=True )
len(df)
# Out:
# 40240

# %% [markdown]
# # Vectorización de textos

# %%
def preprocesar(texto):
  #convierte a minúsculas
  texto = (texto).lower()

  #elimina stopwords
  stop = re.compile(r'\b(' + r'|'.join(stopwords.words('english')) + r')\b\s*')
  texto = stop.sub('', texto) 

  #Quitar puntuación y números
  texto = re.sub('[^ña-z]+', ' ', texto)

  #lematizar y quedarnos con palabras que tengan más de tres caracteres
  lemmatizer = WordNetLemmatizer()
  texto = texto.split()
  texto = ' '.join([lemmatizer.lemmatize(i) for i in texto if len(i)>2])
  
  return(texto)

# %%
df['headline_pp']=df['headline_text'].apply(preprocesar)
df.head()
# Out:
#   publish_date                                      headline_text  \
# 0   2020-01-01          a new type of resolution for the new year
# 1   2020-01-01  adelaide records driest year in more than a de...
# 2   2020-01-01  adelaide riverbank catches alight after new ye...
# 3   2020-01-01   adelaides 9pm fireworks spark blaze on riverbank
# 4   2020-01-01  archaic legislation governing nt women propert...
#
#                                          headline_pp
# 0                       new type resolution new year
# 1                 adelaide record driest year decade
# 2  adelaide riverbank catch alight new year eve f...
# 3            adelaide firework spark blaze riverbank
# 4  archaic legislation governing woman property r...

# %%
vectorizer = CountVectorizer(min_df=3, ngram_range=(1,2))
BOW = vectorizer.fit_transform(df['headline_pp'])
BOW.shape
# Out:
# (40240, 17889)

# %%
vocabulario = vectorizer.get_feature_names_out()
len(vocabulario)
# Out:
# 17889

# %%
list(vocabulario)[0:30]
# Out:
# ['aacta',
#  'aaron',
#  'ab',
#  'abandon',
#  'abandoned',
#  'abandoned baby',
#  'abattoir',
#  'abbott',
#  'abc',
#  'abc analyst',
#  'abc china',
#  'abc coronavirus',
#  'abc heywire',
#  'abc investigation',
#  'abc journalist',
#  'abc news',
#  'abc radio',
#  'abc reader',
#  'abc reporter',
#  'abc rural',
#  'abc tasmania',
#  'abducted',
#  'abduction',
#  'abdul',
#  'abe',
#  'abf',
#  'able',
#  'ablett',
#  'aboard',
#  'aboriginal']

# %% [markdown]
# # Entrenamiento del modelo

# %%
lda_model=LatentDirichletAllocation(n_components=5,learning_method='online',random_state=42,max_iter=50)

# %%
# %%time
lda_model.fit(BOW) # entrena el modelo y obtienela matriz documento-topico
# Out:
# CPU times: user 4min 22s, sys: 1.52 s, total: 4min 23s
# Wall time: 4min 25s
# LatentDirichletAllocation(learning_method='online', max_iter=50, n_components=5,
#                           random_state=42)

# %% [markdown]
# ### Distribución de temas en cada noticia  (O)

# %%
doc_top = pd.DataFrame(lda_model.transform(BOW))
print(doc_top.shape)
doc_top.head()
# Out:
# (40240, 5)
#           0         1         2         3         4
# 0  0.199279  0.028573  0.184108  0.028812  0.559229
# 1  0.025041  0.025081  0.025191  0.025001  0.899686
# 2  0.693037  0.016930  0.017398  0.112981  0.159655
# 3  0.365887  0.532855  0.034198  0.033334  0.033726
# 4  0.239982  0.439999  0.040000  0.040000  0.240019

# %%
doc_top.sum(axis=1)
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 40235    1.0
# 40236    1.0
# 40237    1.0
# 40238    1.0
# 40239    1.0
# Length: 40240, dtype: float64

# %%
pd.merge(df, doc_top, left_index=True, right_index=True)
# Out:
#       publish_date                                      headline_text  \
# 0       2020-01-01          a new type of resolution for the new year
# 1       2020-01-01  adelaide records driest year in more than a de...
# 2       2020-01-01  adelaide riverbank catches alight after new ye...
# 3       2020-01-01   adelaides 9pm fireworks spark blaze on riverbank
# 4       2020-01-01  archaic legislation governing nt women propert...
# ...            ...                                                ...
# 40235   2020-12-31  what abc readers learned from 2020 looking bac...
# 40236   2020-12-31  what are the south african and uk variants of ...
# 40237   2020-12-31  what victorias coronavirus restrictions mean f...
# 40238   2020-12-31  whats life like as an american doctor during c...
# 40239   2020-12-31  womens shed canberra reskilling unemployed pan...
#
#                                              headline_pp         0         1  \
# 0                           new type resolution new year  0.199279  0.028573
# 1                     adelaide record driest year decade  0.025041  0.025081
# 2      adelaide riverbank catch alight new year eve f...  0.693037  0.016930
# 3                adelaide firework spark blaze riverbank  0.365887  0.532855
# 4      archaic legislation governing woman property r...  0.239982  0.439999
# ...                                                  ...       ...       ...
# 40235               abc reader learned looking back year  0.020312  0.143208
# 40236                        south african variant covid  0.033334  0.366653
# 40237  victoria coronavirus restriction mean new year...  0.374914  0.015385
# 40238              whats life like american doctor covid  0.149999  0.399955
# 40239  woman shed canberra reskilling unemployed pand...  0.033899  0.033334
#
#               2         3         4
# 0      0.184108  0.028812  0.559229
# 1      0.025191  0.025001  0.899686
# 2      0.017398  0.112981  0.159655
# 3      0.034198  0.033334  0.033726
# 4      0.040000  0.040000  0.240019
# ...         ...       ...       ...
# 40235  0.020001  0.696724  0.119755
# 40236  0.034192  0.366597  0.199225
# 40237  0.015421  0.578345  0.015936
# 40238  0.025230  0.274785  0.150030
# 40239  0.199753  0.033334  0.699682
#
# [40240 rows x 8 columns]

# %% [markdown]
# ## Distribución de palabras en cada tema ($\mu$)

# %%
μs = pd.DataFrame(lda_model.exp_dirichlet_component_,
                         columns=vocabulario)
print(μs.shape)
μs.head()
# Out:
# (5, 17889)
#           aacta         aaron            ab       abandon     abandoned  \
# 0  8.055449e-08  8.394868e-08  8.290329e-08  8.597120e-08  2.583584e-04
# 1  5.479865e-05  9.063174e-08  8.905556e-08  9.687651e-08  9.750708e-08
# 2  8.937147e-08  4.060349e-05  8.383059e-08  1.453180e-04  9.298521e-08
# 3  6.273702e-08  6.972041e-08  2.316852e-04  7.293856e-08  7.287104e-08
# 4  7.476241e-08  7.598304e-08  7.571805e-08  7.872401e-08  8.212703e-08
#
#    abandoned baby      abattoir        abbott           abc   abc analyst  \
# 0    4.856293e-05  8.847004e-08  1.606078e-04  9.363507e-08  7.998740e-08
# 1    9.057895e-08  1.858361e-04  9.396337e-08  2.232402e-03  8.905083e-08
# 2    9.201562e-08  9.192969e-08  8.576488e-08  8.999806e-08  8.442723e-08
# 3    6.769409e-08  1.518431e-04  6.654507e-08  1.102018e-03  4.525883e-05
# 4    7.659022e-08  8.005516e-08  7.808353e-08  8.047507e-08  7.373083e-08
#
#    ...         zlate  zlate cvetanovski        zodiac           zoe  \
# 0  ...  8.007074e-08       8.007074e-08  8.259616e-08  8.386654e-08
# 1  ...  8.799667e-08       8.799667e-08  5.563037e-05  9.990114e-08
# 2  ...  9.009405e-08       9.009405e-08  8.384335e-08  4.324443e-05
# 3  ...  6.478957e-08       6.478957e-08  6.274360e-08  6.877298e-08
# 4  ...  3.923673e-05       3.923673e-05  7.701010e-08  7.356924e-08
#
#          zombie          zone           zoo          zoom    zuckerberg  \
# 0  5.527396e-05  1.010441e-07  8.700062e-08  2.163308e-04  7.941396e-08
# 1  9.725587e-08  9.643613e-08  9.649468e-08  1.009692e-07  4.355457e-05
# 2  8.518493e-08  6.206949e-04  5.930656e-04  9.235608e-08  8.460164e-08
# 3  6.273777e-08  7.352419e-08  6.603361e-08  6.686220e-08  7.040503e-08
# 4  7.502965e-08  8.437525e-08  8.074065e-08  7.812199e-08  7.355545e-08
#
#          zverev
# 0  8.010021e-08
# 1  1.318067e-04
# 2  8.441493e-08
# 3  6.290800e-08
# 4  7.354552e-08
#
# [5 rows x 17889 columns]

# %%
μs.sum(axis=1)
# Out:
# 0    0.927392
# 1    0.919499
# 2    0.923305
# 3    0.943717
# 4    0.931934
# dtype: float64

# %% [markdown]
# # Visualización del modelo

# %%
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()

pyLDAvis.sklearn.prepare(lda_model, BOW, vectorizer)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 3      0.131129  0.306691       1        1  23.992173
# 4      0.065478 -0.081411       2        1  20.763131
# 0      0.127913 -0.010986       3        1  19.258421
# 2      0.055288 -0.264012       4        1  18.389721
# 1     -0.379809  0.049718       5        1  17.596554, topic_info=              Term         Freq        Total Category  logprob  loglift
# 4293         covid  3119.000000  3119.000000  Default  30.0000  30.0000
# 2664          case  1245.000000  1245.000000  Default  29.0000  29.0000
# 12751   queensland  1276.000000  1276.000000  Default  28.0000  28.0000
# 3777   coronavirus  7645.000000  7645.000000  Default  27.0000  27.0000
# 14034          say  1011.000000  1011.000000  Default  26.0000  26.0000
# ...            ...          ...          ...      ...      ...      ...
# 8487        island   233.514467   306.766851   Topic5  -5.4600   1.4646
# 10035          may   181.317788   222.501791   Topic5  -5.7130   1.5328
# 12681          qld   222.510624   398.610393   Topic5  -5.5083   1.1545
# 1128    australian   318.044100  1081.600506   Topic5  -5.1511   0.5135
# 1029     australia   230.686734  1893.634630   Topic5  -5.4722  -0.3677
#
# [228 rows x 6 columns], token_table=       Topic      Freq        Term
# term
# 29         3  0.991942  aboriginal
# 57         5  0.993438       abuse
# 97         3  0.993683     accused
# 280        4  0.997653         afl
# 341        4  0.998236        aged
# ...      ...       ...         ...
# 17659      5  0.322659      worker
# 17689      1  0.353843       world
# 17689      3  0.643628       world
# 17784      2  0.716711        year
# 17784      3  0.283463        year
#
# [225 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 5, 1, 3, 2])

# %% [markdown]
# # Guardamos modelo

# %%
import pickle
path = '/content/drive/MyDrive/Modelos/modelosLDA/LDA_sklearn/'
tuple_models = (lda_model, BOW, vectorizer)
pickle.dump(tuple_models, open (path + "tuple_model_news2020.pkl", 'wb'))

# %% [markdown]
# # Leemos el guardado modelo

# %%
import pickle
path = '/content/drive/MyDrive/Modelos/modelosLDA/LDA_sklearn/'
lda_model, BOW, vectorizer = pickle.load(open(path + "tuple_model_news2020.pkl", 'rb'))

# %% [markdown]
# # Entrenamiento del modelo 2

# %%
lda_model2=LatentDirichletAllocation(n_components=4,learning_method='online',random_state=42,max_iter=50)

# %%
# %%time
lda_model2.fit(BOW) # entrena el modelo y obtienela matriz documento-topico
# Out:
# CPU times: user 4min 13s, sys: 1.61 s, total: 4min 15s
# Wall time: 4min 18s
# LatentDirichletAllocation(learning_method='online', max_iter=50, n_components=4,
#                           random_state=42)

# %% [markdown]
# ### Distribución de temas en cada noticia  (O)

# %%
doc_top = pd.DataFrame(lda_model2.transform(BOW))
print(doc_top.shape)
doc_top.head()
# Out:
# (40240, 4)
#           0         1         2         3
# 0  0.370215  0.035973  0.298384  0.295428
# 1  0.156453  0.031325  0.780589  0.031634
# 2  0.021096  0.020916  0.139193  0.818795
# 3  0.041673  0.407005  0.042950  0.508373
# 4  0.050425  0.050350  0.849224  0.050001

# %%
doc_top.sum(axis=1)
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 40235    1.0
# 40236    1.0
# 40237    1.0
# 40238    1.0
# 40239    1.0
# Length: 40240, dtype: float64

# %%
pd.merge(df, doc_top, left_index=True, right_index=True)
# Out:
#       publish_date                                      headline_text  \
# 0       2020-01-01          a new type of resolution for the new year
# 1       2020-01-01  adelaide records driest year in more than a de...
# 2       2020-01-01  adelaide riverbank catches alight after new ye...
# 3       2020-01-01   adelaides 9pm fireworks spark blaze on riverbank
# 4       2020-01-01  archaic legislation governing nt women propert...
# ...            ...                                                ...
# 40235   2020-12-31  what abc readers learned from 2020 looking bac...
# 40236   2020-12-31  what are the south african and uk variants of ...
# 40237   2020-12-31  what victorias coronavirus restrictions mean f...
# 40238   2020-12-31  whats life like as an american doctor during c...
# 40239   2020-12-31  womens shed canberra reskilling unemployed pan...
#
#                                              headline_pp         0         1  \
# 0                           new type resolution new year  0.370215  0.035973
# 1                     adelaide record driest year decade  0.156453  0.031325
# 2      adelaide riverbank catch alight new year eve f...  0.021096  0.020916
# 3                adelaide firework spark blaze riverbank  0.041673  0.407005
# 4      archaic legislation governing woman property r...  0.050425  0.050350
# ...                                                  ...       ...       ...
# 40235               abc reader learned looking back year  0.025003  0.123725
# 40236                        south african variant covid  0.374712  0.374964
# 40237  victoria coronavirus restriction mean new year...  0.535564  0.019255
# 40238              whats life like american doctor covid  0.447155  0.241130
# 40239  woman shed canberra reskilling unemployed pand...  0.597750  0.042198
#
#               2         3
# 0      0.298384  0.295428
# 1      0.780589  0.031634
# 2      0.139193  0.818795
# 3      0.042950  0.508373
# 4      0.849224  0.050001
# ...         ...       ...
# 40235  0.025499  0.825773
# 40236  0.208652  0.041672
# 40237  0.019901  0.425280
# 40238  0.031254  0.280461
# 40239  0.318383  0.041669
#
# [40240 rows x 7 columns]

# %% [markdown]
# ## Distribución de palabras en cada tema ($\mu$)

# %%
μs = pd.DataFrame(lda_model2.exp_dirichlet_component_,
                         columns=vocabulario)
print(μs.shape)
μs.head()
# Out:
# (4, 17889)
#           aacta         aaron            ab       abandon     abandoned  \
# 0  1.342399e-07  1.378323e-07  1.717455e-04  1.597560e-07  1.508602e-04
# 1  2.931848e-07  3.568762e-05  2.213863e-07  1.256446e-04  4.679033e-07
# 2  4.147231e-05  2.057025e-07  1.923475e-07  2.123087e-07  2.406799e-07
# 3  1.951538e-07  2.147300e-07  2.048794e-07  3.004904e-07  2.115837e-07
#
#    abandoned baby      abattoir        abbott           abc   abc analyst  \
# 0    1.647154e-07  9.427261e-05  9.402175e-05  1.640185e-07  1.456304e-07
# 1    4.485982e-05  1.833349e-04  2.354529e-07  2.809044e-07  5.280814e-05
# 2    1.890966e-07  2.351272e-07  2.206493e-07  2.448707e-07  1.889143e-07
# 3    2.022671e-07  2.547691e-07  2.712124e-07  2.914184e-03  1.998794e-07
#
#    ...         zlate  zlate cvetanovski        zodiac           zoe  \
# 0  ...  1.341521e-07       1.341521e-07  1.375759e-07  1.465176e-07
# 1  ...  2.377463e-07       2.377463e-07  4.676785e-05  2.196424e-07
# 2  ...  1.889621e-07       1.889621e-07  1.962005e-07  3.434275e-05
# 3  ...  3.658458e-05       3.658458e-05  2.117569e-07  2.056823e-07
#
#          zombie          zone           zoo          zoom    zuckerberg  \
# 0  1.378864e-07  1.977326e-07  1.733638e-07  7.698171e-05  1.438595e-07
# 1  3.343146e-07  5.352001e-04  2.611033e-07  7.399884e-05  3.659349e-05
# 2  2.398229e-07  4.359226e-07  4.625539e-04  2.357065e-07  1.890898e-07
# 3  4.704205e-05  2.175194e-07  2.232687e-07  2.686084e-07  2.571724e-07
#
#          zverev
# 0  1.346116e-07
# 1  1.099895e-04
# 2  1.931730e-07
# 3  1.980412e-07
#
# [4 rows x 17889 columns]

# %%
μs.sum(axis=1)
# Out:
# 0    0.948750
# 1    0.921152
# 2    0.927662
# 3    0.927779
# dtype: float64

# %% [markdown]
# # Visualización del modelo 2

# %%
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()

pyLDAvis.sklearn.prepare(lda_model, BOW, vectorizer)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0     -0.245653 -0.005307       1        1  33.587682
# 3     -0.002163 -0.279796       2        1  22.777165
# 2     -0.047451  0.251199       3        1  22.690789
# 1      0.295267  0.033904       4        1  20.944365, topic_info=              Term         Freq        Total Category  logprob  loglift
# 3777   coronavirus  6138.000000  6138.000000  Default  30.0000  30.0000
# 4293         covid  3432.000000  3432.000000  Default  29.0000  29.0000
# 12751   queensland  1439.000000  1439.000000  Default  28.0000  28.0000
# 5688      election   964.000000   964.000000  Default  27.0000  27.0000
# 1904        border   980.000000   980.000000  Default  26.0000  26.0000
# ...            ...          ...          ...      ...      ...      ...
# 1759         black   181.661023   192.726321   Topic4  -5.8853   1.5042
# 12681          qld   298.312564   564.783796   Topic4  -5.3893   0.9250
# 7232    government   308.326654   739.346948   Topic4  -5.3563   0.6887
# 1029     australia   295.260213  1632.754535   Topic4  -5.3996  -0.1469
# 2347      business   194.628810   399.304697   Topic4  -5.8163   0.8447
#
# [205 rows x 6 columns], token_table=       Topic      Freq       Term
# term
# 138        1  0.010254        act
# 138        3  0.987828        act
# 280        2  0.998549        afl
# 341        3  0.998254       aged
# 342        3  0.998273  aged care
# ...      ...       ...        ...
# 17784      1  0.063083       year
# 17784      2  0.215223       year
# 17784      3  0.690197       year
# 17784      4  0.031541       year
# 17849      2  0.995559    zealand
#
# [241 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 4, 3, 2])
